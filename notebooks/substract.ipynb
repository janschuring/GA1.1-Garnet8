# %%
def substract(a,b):
    return a-b
# print(substract(6,5)) #Commented Out to obtain only one result

def distance_from_zero(x):
    return abs(substract(x, 0))
print(distance_from_zero(-10))
# Out:
# 10
