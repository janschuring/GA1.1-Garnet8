# %%
def multiply(a, b):
    return a * b
print(multiply(5,2))
print(multiply(6,7))
print(multiply(31,2))

# %%
def square(x):
    return multiply(x, x)

# %%
print(square(5))
print(square(10))
print(square(-3))
